# %% [markdown]
# # Testing
# Test connectivity to Google Colab from VS code

# %%
#

# %%
# Verify GPU availability using PyTorch

import torch
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device} -1")
# Out:
# Using device: cpu
