# %% [markdown]
# # 05 Gradient Boosting - Email Spam Classification
#
# This is a complete, standalone pipeline for training a Gradient Boosting model on dirty email data.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import re
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import classification_report, confusion_matrix

sns.set(style='whitegrid')

# %% [markdown]
# ### 1. Data Cleaning & Preprocessing
# Cleaning the headers, duplicates, and HTML noise.

# %%
df = pd.read_csv('../_data/email_spam.csv')
df.columns = [c.lower().replace('-', '_').replace(' ', '_') for c in df.columns]
df = df.drop_duplicates()

def clean_text(text):
    text = re.sub('<.*?>', '', str(text))
    return text.strip().lower()

df['text_clean'] = df['message_content'].apply(clean_text)
df['is_spam'] = df['target_label'].apply(lambda x: 1 if str(x).lower().strip() in ['1', 'spam', 's_p_a_m'] else 0)

X_train, X_test, y_train, y_test = train_test_split(df['text_clean'], df['is_spam'], test_size=0.2, random_state=42)

# %% [markdown]
# ### 2. Pipeline Building & Training

# %%
pipeline = Pipeline([
    ('tfidf', TfidfVectorizer(stop_words='english', max_features=2000)),
    ('clf', GradientBoostingClassifier(n_estimators=100, learning_rate=0.1, max_depth=3))
])

pipeline.fit(X_train, y_train)
print("Gradient Boosting model trained.")
# Out:
# Gradient Boosting model trained.

# %% [markdown]
# ### 3. Evaluation & Visualization

# %%
y_pred = pipeline.predict(X_test)
plt.figure(figsize=(6, 4))
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='d', cmap='YlGnBu')
plt.title('Confusion Matrix - Gradient Boosting')
plt.show()

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.49      0.52      0.51       367
#            1       0.47      0.44      0.45       353
#
#     accuracy                           0.48       720
#    macro avg       0.48      0.48      0.48       720
# weighted avg       0.48      0.48      0.48       720

# %% [markdown]
# ### 4. Model Saving

# %%
joblib.dump(pipeline, '../_model/email_classification_gradient_boosting.joblib')
print("Model saved.")
# Out:
# Model saved.
